# %%
 #question 1
fruits=["apple","apricot","banana","banana","apple","orange","orange","grapes","grapes"]
unique_fruits = []
for fruit in fruits:
    if fruit not in unique_fruits:
        unique_fruits.append(fruit)
print(unique_fruits)
# Out:
# ['apple', 'apricot', 'banana', 'orange', 'grapes']

# %%
a = 144
a**0.5
print(a**0.5)
# Out:
# 12.0

# %%
#square root of 225
a = 225
a**0.5
print(a**0.5)
# Out:
# 15.0
