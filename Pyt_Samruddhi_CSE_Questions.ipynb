# %%
#question 1
print('Hello World!')
print('Have a good day.')
print('Learning Python is fun!')
# Out:
# Hello World!
# Have a good day.
# Learning Python is fun!

# %%
# question 2
print("Hello"); print("How are you?"); print("Bye bye!")
# Out:
# Hello
# How are you?
# Bye bye!

# %%
# question 3
age = 25
print("I am",age, "years old" )
# Out:
# I am 25 years old

# %%
#question 4 
Name = "Samruddhi"
age = 19
print("Name:",Name)
print("age:",age)
# Out:
# Name: Samruddhi
# age: 19

# %%
#question 5
x,y,z = "Apple","Mango","Banana"
print(x)
print(y)
print(z)
# Out:
# Apple
# Mango
# Banana

# %%
#question 6
#convert integer 5 to a string
num1 =5
str_num=str(num1)
print("String value:", str_num)
print("Type:",type(str_num))

#converts 7.8 to an integer
num2 = 7.8
int_num=int(num2)
print("Integer value:", int_num)
print("Type:",type(int_num))

#converts 9 t0 a float
num3 = 9
float_num=float(num3)
print("float vlaue:", float_num)
print("Type:",type(float_num))
# Out:
# String value: 5
# Type: <class 'str'>
# Integer value: 7
# Type: <class 'int'>
# float vlaue: 9.0
# Type: <class 'float'>

# %%
#queston 7
x = 10
x = str(x)

print(x)
print(type(x))
# Out:
# 10
# <class 'str'>

# %%
#question 8
num = 20 
num = float(num)

print(num)
print(type(num))
# Out:
# 20.0
# <class 'float'>
